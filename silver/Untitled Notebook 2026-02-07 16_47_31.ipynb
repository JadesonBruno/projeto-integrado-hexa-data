# %%
configs = {
  "fs.azure.account.key.aceleragrupo5sa.blob.core.windows.net": dbutils.secrets.get("acelera-grupo-5-kv", "tgt-key-storage-account")
}

# %%
dbutils.fs.mounts()

# %%
TGT_BRONZE_PATH = f"abfss://bronze@aceleragrupo5sa.dfs.core.windows.net"
display(dbutils.fs.ls(TGT_BRONZE_PATH))

# %%
SRC_BRONZE_BALANCE_PATH = f"wasbs://balancacomercial@landingbeca2026jan.blob.core.windows.net"
display(dbutils.fs.ls(SRC_BRONZE_BALANCE_PATH))

# %%
df = spark.table("hive_metastore.bronze_balancacomercial.exp")
display(df)

# %%
# %sql
SELECT * 
FROM hive_metastore.bronze_balancacomercial.exp;
