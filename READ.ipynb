# %%
TGT_STORAGE_ACCOUNT = dbutils.secrets.get(scope="secrets-kv", key="tgt-storage-account")
TGT_CONTAINER = dbutils.secrets.get(scope="secrets-kv", key="tgt-container")
TGT_SAS_TOKEN = dbutils.secrets.get(scope="secrets-kv", key="tgt-sas-token")

# Configuring SAS for Lakehouse Container
spark.conf.set(
    f"fs.azure.sas.{TGT_CONTAINER}.{TGT_STORAGE_ACCOUNT}.blob.core.windows.net",
    TGT_SAS_TOKEN
)

#LAKEHOUSE_BASE_PATH = f"wasbs://{TGT_CONTAINER}@{TGT_STORAGE_ACCOUNT}.blob.core.windows.net/bronze_1"

# %%
# Configuring SAS TOKEN in Spark for Target
spark.conf.set(
    f"fs.azure.account.auth.type.{TGT_STORAGE_ACCOUNT}.dfs.core.windows.net",
    "SAS"
)
 
spark.conf.set(
    f"fs.azure.sas.token.provider.type.{TGT_STORAGE_ACCOUNT}.dfs.core.windows.net",
    "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider"
)
 
spark.conf.set(
    f"fs.azure.sas.fixed.token.{TGT_STORAGE_ACCOUNT}.dfs.core.windows.net",
    TGT_SAS_TOKEN
)

# %%
caminho_balanca = "abfss://acelera-databricks-2026-uc@aceleragrupo5sa.dfs.core.windows.net/silver/balance/silver_exp/"

# %%
df = spark.read.format("delta").load(caminho_balanca)

# %%
df.printSchema()
df.show(10)

# %%
df.display(10)

# %%
df.printSchema()
df.show(10)

# %%
spark.sql("""CREATE DATABASE IF NOT EXISTS bronze_1""")

# %%
spark.sql("""DROP TABLE bronze_1.cnpj_empresas """)

# %%
spark.sql(""" CREATE TABLE IF NOT EXISTS 
          bronze_1.cnpj_empresas 
          USING DELTA LOCATION 'abfss://acelera-databricks-2026-uc@aceleragrupo5sa.dfs.core.windows.net/bronze_1/cnpj/empresas/' """)
